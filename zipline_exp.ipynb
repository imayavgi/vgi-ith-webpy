# %%
import zipline
# %matplotlib inline
# %load_ext zipline
# Out:
# The zipline extension is already loaded. To reload it, use:
#   %reload_ext zipline

# %%
# %%zipline --start=2011-1-1 --end=2011-2-1 -o perf
# import sys
# import logbook
# import numpy as np
#
# zipline_logging = logbook.NestedSetup([
#     logbook.NullHandler(),
#     logbook.StreamHandler(sys.stdout, level=logbook.INFO),
#     logbook.StreamHandler(sys.stderr, level=logbook.ERROR),
# ])
#
# log = logbook.Logger('Logbook')
#
# zipline_logging.push_application()
#
#
# def initialize(context):
#     #attach_pipeline(make_pipeline(), 'exp_pipeline')
#     log.info('Initialize called')
#
# def make_pipeline():
#     log.info(' Make pipe line called')
#
# def handle_data(context, data):
#     log.info('%s Handle Data called' % data)
#
# def before_trading_start(context, data):
#     log.info(' Before trading start calls')
#
# def analyze(context, perf):
#     log.info('Analyze called')
# Out:
# [2016-08-18 19:01:30.001811] INFO: Logbook: Initialize called
# [2016-08-18 19:01:30.005147] INFO: Logbook:  Before trading start calls
# [2016-08-18 19:01:30.010371] INFO: Logbook: <zipline._protocol.BarData object at 0x118240b90> Handle Data called
# [2016-08-18 19:01:30.019160] INFO: Logbook:  Before trading start calls
# [2016-08-18 19:01:30.021383] INFO: Logbook: <zipline._protocol.BarData object at 0x118240b90> Handle Data called
# [2016-08-18 19:01:30.033059] INFO: Logbook:  Before trading start calls
# [2016-08-18 19:01:30.034817] INFO: Logbook: <zipline._protocol.BarData object at 0x118240b90> Handle Data called
# [2016-08-18 19:01:30.056016] INFO: Logbook:  Before trading start calls
# [2016-08-18 19:01:30.086415] INFO: Logbook: <zipline._protocol.BarData object at 0x118240b90> Handle Data called
# [2016-08-18 19:01:30.093810] INFO: Logbook:  Before trading start calls
# ...
